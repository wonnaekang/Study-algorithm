# %% [markdown]
# # 그래프 탐색 알고리즘
# - 많은 양의 데이터 중에서 원하는 데이터를 찾는 과정
# - 코딩 테스트에서 매우 자주 등장하는 유형

# %% [markdown]
# ## *스택 자료구조
# - 먼저 들어 온 데이터가 나중에 나가는 형식
# - 입구와 출구가 동일한 형태로 스택을 시각화

# %%
# ex
stack=[]

stack.append(5)
stack.append(3)
stack.append(7)
stack.append(5)
stack.pop()
stack.append(1)
stack.append(4)
stack.pop()

print(stack[::-1])#최상단 원소부터
print(stack)#최하단 원소부터
# Out:
# [1, 7, 3, 5]
# [5, 3, 7, 1]

# %% [markdown]
# # *큐 자료구조
# - 먼저 들어 온 데이터가 먼저 나가는 형식
# - 큐는 입구와 출구가 모두 뚫려 있는 터널과 같은 형태로 시각화

# %%
#ex
from collections import deque

#큐 구현을 위해 deque 라이브러리 사용
queue = deque()

queue.append(5)
queue.append(3)
queue.append(7)
queue.append(5)
queue.popleft()
queue.append(1)
queue.append(4)
queue.popleft()

print(queue)# 먼저 들어온 순서대로 출력
queue.reverse()# 역순으로 바꾸기
print(queue)
# Out:
# deque([7, 5, 1, 4])
# deque([4, 1, 5, 7])

# %% [markdown]
# # 재귀 함수
# - 자기 자신을 다시 호출하는 함수
# - 문자열을 무한히 출력
# - 어느 정도 출력하다가 최대 재귀 깊이 초과 메시지가 출력

# %%
def recursive_fuc(i):
    if i ==100:
        return
    print(i, '번째 재귀함수에서',i+1,'번쨰 재귀함수 호출')
    recursive_fuc(i+1)
    print(i, '번째 재귀함수를 종료합니다.')
    
recursive_fuc(1)
# Out:
# 1 번째 재귀함수에서 2 번쨰 재귀함수 호출
# 2 번째 재귀함수에서 3 번쨰 재귀함수 호출
# 3 번째 재귀함수에서 4 번쨰 재귀함수 호출
# 4 번째 재귀함수에서 5 번쨰 재귀함수 호출
# 5 번째 재귀함수에서 6 번쨰 재귀함수 호출
# 6 번째 재귀함수에서 7 번쨰 재귀함수 호출
# 7 번째 재귀함수에서 8 번쨰 재귀함수 호출
# 8 번째 재귀함수에서 9 번쨰 재귀함수 호출
# 9 번째 재귀함수에서 10 번쨰 재귀함수 호출
# 10 번째 재귀함수에서 11 번쨰 재귀함수 호출
# 11 번째 재귀함수에서 12 번쨰 재귀함수 호출
# 12 번째 재귀함수에서 13 번쨰 재귀함수 호출
# 13 번째 재귀함수에서 14 번쨰 재귀함수 호출
# 14 번째 재귀함수에서 15 번쨰 재귀함수 호출
# 15 번째 재귀함수에서 16 번쨰 재귀함수 호출
# 16 번째 재귀함수에서 17 번쨰 재귀함수 호출
# 17 번째 재귀함수에서 18 번쨰 재귀함수 호출
# 18 번째 재귀함수에서 19 번쨰 재귀함수 호출
# 19 번째 재귀함수에서 20 번쨰 재귀함수 호출
# 20 번째 재귀함수에서 21 번쨰 재귀함수 호출
# 21 번째 재귀함수에서 22 번쨰 재귀함수 호출
# 22 번째 재귀함수에서 23 번쨰 재귀함수 호출
# 23 번째 재귀함수에서 24 번쨰 재귀함수 호출
# 24 번째 재귀함수에서 25 번쨰 재귀함수 호출
# 25 번째 재귀함수에서 26 번쨰 재귀함수 호출
# 26 번째 재귀함수에서 27 번쨰 재귀함수 호출
# 27 번째 재귀함수에서 28 번쨰 재귀함수 호출
# 28 번째 재귀함수에서 29 번쨰 재귀함수 호출
# 29 번째 재귀함수에서 30 번쨰 재귀함수 호출
# 30 번째 재귀함수에서 31 번쨰 재귀함수 호출
# 31 번째 재귀함수에서 32 번쨰 재귀함수 호출
# 32 번째 재귀함수에서 33 번쨰 재귀함수 호출
# 33 번째 재귀함수에서 34 번쨰 재귀함수 호출
# 34 번째 재귀함수에서 35 번쨰 재귀함수 호출
# 35 번째 재귀함수에서 36 번쨰 재귀함수 호출
# ...

# %% [markdown]
# # 팩토리얼 구현 예제

# %%
def factorial_recursive(n):
    if n <=1:
        return 1
    return n* factorial_recursive(n-1)

print(factorial_recursive(5))
# Out:
# 120

# %% [markdown]
# # 유클리드 호제법

# %%
#두 수의 최대 공약수
def gcd(a,b):
    if a%b==0:
        return b
    else:
        return gcd(b,a%b)
print(gcd(192,162))
# Out:
# 6

# %% [markdown]
# # DFS 깊이 우선 탐색 그래프에서 깊은 부분
# # DFS는 스택 자료구조를 이용
# - 탐색 시작 노드를 스택에 삽입하고 방문 처리
# - 스택의 최상단 노드에 방문하지 않은 인접한 노드가 하나라도 있으면 그 노드를 스택에 넣고 처리, 방문하지 않은 인접 노드가 없으면 최상단 노드를 꺼냄
# - 더 이상 2번의 과정을 수행할 수 없을 때까지 반복

# %%
# DFS 메서드 정의
def dfs(graph, v, visited):
    #현재 노드를 방문 처리
    visited[v]=True
    print(v,end='')
    #현재 노드와 연결된 다른 노드를 재귀적으로 방문
    for i in graph[v]:
        if not visited[i]:
            dfs(graph,i,visited)
            
            
#각 노드가 연결된 정보를 표현 (2차원 리스트)
graph =[[],[2,3,4],[1,7],[1,4,5],[3,5],[3,4],[7],[2,6,8],[1,7]]

#각 노드가 방문된 정보를 표현(1차원 리스트)
visited=[False]*9

#정의된 dfs 함수 호출
dfs(graph,1,visited)
# Out:
# 12768345

# %% [markdown]
# # BFS는 너비 우선 탐색이라고 부른다.
# # 그래프에서 가까운 노드부터 우선적으로 탐색
# - 탐색 시작 노드를 큐에 삽입하고 망문 처리
# - 큐에서 노드를 꺼내 ㄴ뒤에 해당 노드의 인접 노드 중에서 방문하지 않은 노드를 모두 큐에 삽입하고 방문 처리
# - 더 이상 2번의 과정을 수행할 수 없을 때까지 반복

# %%
from collections import deque

# BFS 메서드 정의
def bfs(graph, start, visited):
    #큐 구현을 위해 deque라이브러리 사용
    queue = deque([start])
    #현재 노드를 방문 처리
    visited[start]=True
    #큐가 빌 때까지 반복
    while queue:
        #큐에서 하나의 원소를 뽑아 출력하기
        v = queue.popleft()
        print(v, end='')
        #아직 방문하지 않은 인접한 우너소들을 큐에 삽입
        for i in graph[v]:
            if not visited[i]:
                queue.append(i)
                visited[i] = True
            
            
#각 노드가 연결된 정보를 표현 (2차원 리스트)
graph =[[],[2,3,8],[1,7],[1,4,5],[3,5],[3,4],[7],[2,6,8],[1,7]]

#각 노드가 방문된 정보를 표현(1차원 리스트)
visited=[False]*9

#정의된 dfs 함수 호출
bfs(graph,1,visited)
# Out:
# 12387456

# %% [markdown]
# # 음료수 얼려 먹기
# # n*m크기 얼음 틀
# - 구멍 0 , 칸막이 1
# - 구멍 끼리 상하좌우 붙어있으면 연결
# - 총 아이스크림 개수 구하는 프로그램

# %%
# DFS로 특정 노드를 방문하고 연결된 모든 노드들도 방문
def dfs(x,y):
    # 주어진 범위를 벗어나는 경우에는 즉시 종료
    if x<=-1 or x>=n or y<=-1 or y>=m:
        return False
    # 현재 노드를 아직 방문하지 않았따면
    if graph[x][y] == 0:
        # 해당 노드 방문 처리
        graph[x][y] =1
        # 상, 하, 좌, 우 모두 재귀적으로 호출
        dfs(x-1,y)
        dfs(x,y-1)
        dfs(x+1,y)
        dfs(x,y+1)
        return True
    return False



n, m = map(int, input().split())

#2차원 리스트의 맵 정보 입력 받기
graph =[]
for i in range(n):
    graph.append(list(map(int,input())))
    
# 모든 노드에 대하여 음료수 채우기
result = 0
for i in range(n):
    for j in range(m):
        #현재 위치에서 dfs 수행
        if dfs(i,j)==True:
            result +=1
print(result)
# Out:
# 3 3
# 111
# 101
# 000
# 1

# %% [markdown]
# # n*m 미로 한번에 한칸씩
# # 괴물 0 없으면 1
# - 움직여야 하는 최소 칸의 개수
# - 칸을 셀 때는 시작 칸과 마지막 칸을 모두 포함

# %%
def bfs(x,y):
    #큐 구현을 위해 deque 라이브러리 사용
    queue = deque()
    queue.append((x,y))
    #큐가 빌 때까지 반복
    while queue :
        x, y = queue.popleft()
        # 현재 위치에서 4가지 방법으로의 위치 확인
        for i in range(4):
            nx = x+dx[i]
            ny = y+dy[i]
            #미로 찾기 공간을 벗어난 경우 무시
            if nx<0 or nx>=n or ny<0 or ny>=m:
                continue
            #벽인 경우 무시
            if graph[nx][ny]== 0:
                continue
            #해당 노드를 처음 방문하는 경우에만 최단 거리 기록
            if graph[nx][ny]==1:
                graph[nx][ny]=graph[x][y]+1
                queue.append((nx,ny))
        #가장 오른쪽 아래까지의 최단 거리 반환
    return graph[n-1][m-1]

n, m = map(int, input().split())
graph = []
for i in range(n):
    graph.append(list(map(int,input())))
dx=[-1,1,0,0]
dy=[0,0,-1,1]

print(bfs(0,0))
# Out:
# 2 2
# 10
# 10
# 0
